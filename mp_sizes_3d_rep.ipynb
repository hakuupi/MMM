# %% [markdown]
# First we generate the data points:

# %%
import sys
# insert at 1, 0 is the script path (or '' in REPL)
sys.path.insert(1, '/Applications/SageMath')
from mp_data import data, description
import numpy as np

# %%
print(description)
# Out:
# [0. polyhedron multiplicity,   1. face dimension,    2. index of poset,   3. size of minimal prez.,   4. semigroup found]

# %%
## to get information, prune by index:

data_with_embedding = []
for elem in data: # create new data list for multiplicity, embedding dimension, and mp size
    if elem[4] != 'na':
        point = [elem[0],len(elem[4]),elem[3]]
        data_with_embedding.append(point) 

d_points = [i for j, i in enumerate(data_with_embedding) if i not in data_with_embedding[:j]] 
#print(list(d_points)) # remove repeats and print

# %% [markdown]
# Then we plot MP size vs embedding dimension vs multiplicity:

# %%
data_points = [[3, 3, 3], [3, 2, 1], [4, 4, 6], [4, 3, 3], [4, 3, 2], [4, 2, 1], [5, 5, 10], [5, 4, 6], [5, 4, 5], [5, 3, 3], [5, 2, 1], [5, 3, 2], [6, 6, 15], [6, 5, 10], [6, 5, 9], [6, 4, 6], [6, 4, 4], [6, 3, 3], [6, 3, 2], [6, 2, 1], [6, 4, 5], [7, 7, 21], [7, 6, 15], [7, 6, 14], [7, 5, 10], [7, 5, 8], [7, 4, 6], [7, 5, 9], [7, 4, 5], [7, 3, 3], [7, 4, 4], [7, 4, 7], [7, 2, 1], [7, 3, 2], [8, 8, 28], [8, 7, 20], [8, 7, 21], [8, 6, 15], [8, 6, 14], [8, 6, 13], [8, 5, 10], [8, 5, 8], [8, 5, 9], [8, 5, 7], [8, 5, 11], [8, 4, 6], [8, 4, 5], [8, 4, 3], [8, 4, 4], [8, 3, 2], [8, 3, 3], [8, 2, 1], [8, 4, 7], [9, 9, 36], [9, 8, 28], [9, 8, 27], [9, 7, 21], [9, 7, 19], [9, 7, 20], [9, 6, 16], [9, 6, 15], [9, 6, 14], [9, 6, 12], [9, 6, 13], [9, 5, 11], [9, 5, 9], [9, 5, 10], [9, 5, 8], [9, 4, 6], [9, 5, 7], [9, 5, 6], [9, 4, 4], [9, 4, 5], [9, 3, 3], [9, 4, 8], [9, 3, 2], [9, 4, 7], [9, 2, 1], [9, 4, 3], [10, 7, 19], [10, 6, 14], [10, 6, 13], [10, 6, 12], [10, 7, 20], [10, 5, 8], [10, 5, 7], [10, 5, 6], [10, 6, 15], [10, 5, 10], [10, 5, 9], [10, 4, 6], [10, 4, 5], [10, 5, 11], [10, 4, 7], [10, 4, 4], [10, 7, 21], [10, 6, 16], [10, 3, 3], [10, 2, 1], [10, 3, 2], [10, 7, 18], [10, 6, 11], [10, 8, 28], [10, 8, 27], [10, 4, 8], [10, 10, 45], [10, 9, 35], [10, 9, 36], [10, 8, 26], [10, 7, 22]]

# %%
    #sage code:
points([tuple(elem) for elem in data_points], size=50, viewer='threejs', online=True)
# Out:
# Graphics3d Object
